# %% [markdown]
# <a href="https://colab.research.google.com/github/donaldong/bpe/blob/main/Explore_GPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# git clone https://github.com/donaldong/bpe.git

import sys
sys.path.append('/content/bpe/4-generate/minGPT')
sys.path.append('/content/bpe/4-generate')

# %%
import torch
from mingpt.utils import set_seed
from mingpt.model import GPT
# create a Trainer object
from mingpt.trainer import Trainer
from TextDataset import TextDataset

# %%
set_seed(3407)

train_dataset = TextDataset(
    '/content/bpe/1-prepare/book1.txt',
    '/content/bpe/2-build_vocab/vocab.bpe',
    seq_len=50)
model_config = GPT.get_default_config()
model_config.model_type = 'gopher-44m'
model_config.vocab_size = 10833
model_config.block_size = train_dataset.seq_len
model = GPT.from_pretrained((model_config)


train_config = Trainer.get_default_config()
train_config.learning_rate = 2e-5 # the model we're using is so small that we can go a bit faster
train_config.max_iters = 300
train_config.num_workers = 0
trainer = Trainer(train_config, model, train_dataset)

def batch_end_callback(trainer):
    if trainer.iter_num % 100 == 0:
        print(f"iter_dt {trainer.iter_dt * 1000:.2f}ms; iter {trainer.iter_num}: train loss {trainer.loss.item():.5f}")
trainer.set_callback('on_batch_end', batch_end_callback)


def generate(prompt='', num_samples=10, steps=50, do_sample=True):
    encoder = train_dataset.encoder
    x = torch.tensor([encoder.encode(prompt)], dtype=torch.long).to(trainer.device)
    x = x.expand(num_samples, -1)
    # forward the model `steps` times to get samples, in a batch
    y = model.generate(x, max_new_tokens=steps, do_sample=do_sample, top_k=40)
    
    for i in range(num_samples):
        out = encoder.decode(y[i].cpu().squeeze().tolist())
        print('-'*80)
        print(out)

while True:
  trainer.run()
  # torch.save(model.state_dict(), 'harryGPT.pt')
  # now let's perform some evaluation
  model.eval()
  generate(prompt='Hello! It is nice to', num_samples=10, steps=100)
# Out:
# number of parameters: 30.79M
# running on device cuda
# iter_dt 0.00ms; iter 0: train loss 9.38515
# iter_dt 226.98ms; iter 100: train loss 6.74791
# iter_dt 227.81ms; iter 200: train loss 5.65313
# --------------------------------------------------------------------------------
# Hello! It is nice to it.
# --------------------------------------------------------------------------------
# Hello! It is nice to Dumbledore the, who Harry’t have, but he was?
# --------------------------------------------------------------------------------
# Hello! It is nice to have and been?
# --------------------------------------------------------------------------------
# Hello! It is nice to was a at and after, not to he said. Hermione, a long, but his’ll to their his eyes havery about no, was all they were was a lot, and
# --------------------------------------------------------------------------------
# Hello! It is nice to be, with’s with a was going to Harry. “I’t they’t have?
# --------------------------------------------------------------------------------
# Hello! It is nice to the door.
# --------------------------------------------------------------------------------
# Hello! It is nice to?
# --------------------------------------------------------------------------------
# Hello! It is nice to be back
# --------------------------------------------------------------------------------
# Hello! It is nice to be,” said Ron, “I’s, but he knew you off to,” said,” said Harry, I’t I’t bed him’s.”
# --------------------------------------------------------------------------------
# Hello! It is nice to his hand.
# iter_dt 222.53ms; iter 0: train loss 5.16699
# iter_dt 223.25ms; iter 100: train loss 4.88919
# iter_dt 226.21ms; iter 200: train loss 4.76331
# --------------------------------------------------------------------------------
# Hello! It is nice to it?”
# --------------------------------------------------------------------------------
# Hello! It is nice to — the other, in a small- will have a bit of as that was for his wand; the train at them,” said
# --------------------------------------------------------------------------------
# Hello! It is nice to a long at this. The forest, the Dursleys had to Harry, of all, Harry there.
# --------------------------------------------------------------------------------
# Hello! It is nice to a it, you.
# --------------------------------------------------------------------------------
# Hello! It is nice to his head. “He’s you could.
# --------------------------------------------------------------------------------
# Hello! It is nice to do you know, Ron, Hagrid like the, Harry and Harry and Harry’s of, the way it were after agers, which of the Stone, and a bit of her. A bit of the ground. What was.
# --------------------------------------------------------------------------------
# Hello! It is nice to get and they. Hermione’s got, in a few when. He had already he had had a him and a few from up the time to he had gone and Ron and Ron.
# --------------------------------------------------------------------------------
# Hello! It is nice to aftery was a school, you — you — Harry.
# --------------------------------------------------------------------------------
# Hello! It is nice to know.”
# --------------------------------------------------------------------------------
# Hello! It is nice to do, which on after, the next to know about after what he’s head, Harry and He could the air, who was too.”
# iter_dt 227.97ms; iter 0: train loss 4.66964
# iter_dt 224.12ms; iter 100: train loss 4.69026
# iter_dt 224.19ms; iter 200: train loss 4.44845
# --------------------------------------------------------------------------------
# Hello! It is nice to their way in the hat took a bit of his own.
# --------------------------------------------------------------------------------
# Hello! It is nice to the dark,” on, which was now, but Professor Drivery to keep it.
# --------------------------------------------------------------------------------
# Hello! It is nice to get a week for. He couldn’t think she’t have to do you. It was a bit, but if what do you. You’s all that they?”
# --------------------------------------------------------------------------------
# Hello! It is nice to keep his parents had after a lot of her eyes.
# --------------------------------------------------------------------------------
# Hello! It is nice to be so much about him, the wall like to be on as all into the forest, I don’t have been there were saying, but that’t know they’s got it. “Ron’d all not been to get us,” he did it a lot of them in the same and then,” said, or me. Then, but Ron. “I see. “How know it’t see you — we ask you’ll — I’m so if
# --------------------------------------------------------------------------------
# Hello! It is nice to be at the library. Harry hadn’t have, as the wall, but they couldn’t it from a giant.
# --------------------------------------------------------------------------------
# Hello! It is nice to be going to be everyonest in my cupboard, a smallery time, and Neville, as the wholeiling, the train was verything and Ron at him to the rest of a lettervered down on his eyes that — how to a small and he’sped to seemed on the giant and the lettercy was going to have of the only it as Dudley’s the giant as he said Ron and Ron
# --------------------------------------------------------------------------------
# Hello! It is nice to do I’ll know if I’ I’.”
# --------------------------------------------------------------------------------
# Hello! It is nice to have a good of it.” It was a bit of Gryffindor in his eyes.
# --------------------------------------------------------------------------------
# Hello! It is nice to be a few-Who was veryone had been by the door from the bed as though he was a small, you must bed into a lot, the table. But he could have a large and there, Hed with the door, and Ron’d back of Gryffindor Houself of the hall. “It’s not really not going to think to get this and Goyle and Harry told him?
# iter_dt 224.17ms; iter 0: train loss 4.12327
# iter_dt 231.93ms; iter 100: train loss 4.14322
# iter_dt 226.41ms; iter 200: train loss 4.10823
# --------------------------------------------------------------------------------
# Hello! It is nice to get back to do if I’ve got about after they were only one of him a lot ...”
# --------------------------------------------------------------------------------
# Hello! It is nice to the boy, with her face?”
# --------------------------------------------------------------------------------
# Hello! It is nice to a funny; he’d get all that’d can tell yeh? You don’t been up the door. It’t think he looked out a few of this,” said Ron. “How’s not to see him.
# --------------------------------------------------------------------------------
# Hello! It is nice to the boy, but Hermione was holding at the air, but Harry might bed to him. “This is all about?” said, he was on about a moment he was coming to the next, he couldn’t tell him. How?”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop this time and he’d got up the let out a few — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to the Dursleys could do I was at Harry in after, and Harry had been already seen a few more than what he took a large and they thought he’d seen a very time to take your. In its feet to get in his father, because he’d a moment to get a large troll was so that, but they were so long and a smalleryoned bed of them. He hadn’t think he was looking into it. And of her
# --------------------------------------------------------------------------------
# Hello! It is nice to see that you’re sure he didn’t think they didn’t best everyone else.”
# --------------------------------------------------------------------------------
# Hello! It is nice to get all — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to a letter it? All, no — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to be coming from one more will be good. The boy, she asked an’ that they’ve never asked up to his robeshed up and he was trying to get him.”
# iter_dt 224.98ms; iter 0: train loss 4.03231
# iter_dt 228.62ms; iter 100: train loss 3.94215
# iter_dt 224.13ms; iter 200: train loss 4.04017
# --------------------------------------------------------------------------------
# Hello! It is nice to be a good reason, that are you’s up in the ground. “He — I don’t see it’ll be a lot better — and — what if he’s you?”
# --------------------------------------------------------------------------------
# Hello! It is nice to get a sharp of its eyes, but it’shed them were almost as though what he thought of a hand to be able to see.
# --------------------------------------------------------------------------------
# Hello! It is nice to a little things!
# --------------------------------------------------------------------------------
# Hello! It is nice to get out into the library, or you.”
# --------------------------------------------------------------------------------
# Hello! It is nice to it in here, you will be soc?”
# --------------------------------------------------------------------------------
# Hello! It is nice to — yer get it?”
# --------------------------------------------------------------------------------
# Hello! It is nice to me, Harry to look for you in front, and the Houself, I’ll see what you not?”
# --------------------------------------------------------------------------------
# Hello! It is nice to him?” he whispered.
# --------------------------------------------------------------------------------
# Hello! It is nice to see what’re not best, Professor Flitwick, and Hermione would keep in the hall. As one o’ that is that Harry’ all about all over in a minutes the table with the forest, he’s no be able to get into the first time out. But it was no one.
# --------------------------------------------------------------------------------
# Hello! It is nice to come in a smalle that was going to the Dursleys. You do that was still.
# iter_dt 222.09ms; iter 0: train loss 3.87182
# iter_dt 224.63ms; iter 100: train loss 3.85273
# iter_dt 226.75ms; iter 200: train loss 3.67653
# --------------------------------------------------------------------------------
# Hello! It is nice to say.”
# --------------------------------------------------------------------------------
# Hello! It is nice to do, I’m saying that? How I don’t go back to come! It must have to be able to do you in that will be a burcy?”
# --------------------------------------------------------------------------------
# Hello! It is nice to the mirror?” said Ron was that Harry’s mouth. “Don’t he’d be able to us a veryone.”
# --------------------------------------------------------------------------------
# Hello! It is nice to find the door, a bus, Potter, Harry, they’re going to hear what with an’ll tell him ...
# --------------------------------------------------------------------------------
# Hello! It is nice to them through, but I’m not a large time.”
# --------------------------------------------------------------------------------
# Hello! It is nice to think of a veryone else.
# --------------------------------------------------------------------------------
# Hello! It is nice to the Dursleys,
# --------------------------------------------------------------------------------
# Hello! It is nice to Harry from the end and afteryone.
# --------------------------------------------------------------------------------
# Hello! It is nice to a big at Hogwarts, I can’t know ... I didn’t want — but not know all. I suppose. If I’ll see you don’t be to talk about the House to tell me an’s not going to see with Quirrell?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be to have been saying?
# iter_dt 223.23ms; iter 0: train loss 3.78620
# iter_dt 222.71ms; iter 100: train loss 3.75152
# iter_dt 226.01ms; iter 200: train loss 3.64927
# --------------------------------------------------------------------------------
# Hello! It is nice to you a wizard, the back to keep one o’ a good.”
# --------------------------------------------------------------------------------
# Hello! It is nice to make a very important a good to tell me how to be too much.”
# --------------------------------------------------------------------------------
# Hello! It is nice to make the air, and you’ll be in the House will do it, I’ll be at all?”
# --------------------------------------------------------------------------------
# Hello! It is nice to get use you and do it, to stand at all. I’ll be.”
# --------------------------------------------------------------------------------
# Hello! It is nice to us?”
# --------------------------------------------------------------------------------
# Hello! It is nice to say the Gryffindor was in the floor!”
# --------------------------------------------------------------------------------
# Hello! It is nice to bed to hear that it, who’s, Harry’s bestions if I can tell me? All it’s why it’s all, I thought yeh’ll be in it’s all that.”
# --------------------------------------------------------------------------------
# Hello! It is nice to me?”
# --------------------------------------------------------------------------------
# Hello! It is nice to find out for our dormitory, you would never think they’re going to be here that did. I’ve just got back to come on here in to know — what I wouldn’t bestly.”
# --------------------------------------------------------------------------------
# Hello! It is nice to take the same, there is something?”
# iter_dt 225.57ms; iter 0: train loss 3.60927
# iter_dt 224.80ms; iter 100: train loss 3.60660
# iter_dt 223.33ms; iter 200: train loss 3.46687
# --------------------------------------------------------------------------------
# Hello! It is nice to get us a moment, I will be taken to make him about you — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to make their way?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be all your parenny, I think they’ve been talking. And then, I’ll keep me.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be at these.”
# --------------------------------------------------------------------------------
# Hello! It is nice to us if they found out of yeh, the last. Harry, he wasn’t want to try it.
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to do you, it.
# --------------------------------------------------------------------------------
# Hello! It is nice to stop him. That’s not a hundred and three of course, we are some of you’re going to tell them, Harry, but he didn’t he was only to bed that, but he was a bit about. His face when she was so she was in his feet from behind his mother and looked at once.
# --------------------------------------------------------------------------------
# Hello! It is nice to be up for him when I will be in your family like a large time I didn’t see for Gryffindor.”
# --------------------------------------------------------------------------------
# Hello! It is nice to his head, he could see him was too much.
# iter_dt 231.88ms; iter 0: train loss 3.49047
# iter_dt 225.44ms; iter 100: train loss 3.42163
# iter_dt 224.27ms; iter 200: train loss 3.34428
# --------------------------------------------------------------------------------
# Hello! It is nice to go. There did not to take, do use the way again?”
# --------------------------------------------------------------------------------
# Hello! It is nice to do? And what?”
# --------------------------------------------------------------------------------
# Hello! It is nice to go!”
# --------------------------------------------------------------------------------
# Hello! It is nice to do,
# --------------------------------------------------------------------------------
# Hello! It is nice to you all a very good, but I don’t know what I know where You mean everyone in my first.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be able to bed.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be able to Dumbledore and Goyle, I’m going back! I’m not see a single-Know-Who are in a few second!”
# --------------------------------------------------------------------------------
# Hello! It is nice to me off to the first times in my parents?”
# --------------------------------------------------------------------------------
# Hello! It is nice to a few words. It might’s gone, but the Stone before we have thought we were still in here — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to catch me, you think
# iter_dt 224.90ms; iter 0: train loss 3.34683
# iter_dt 226.93ms; iter 100: train loss 3.23984
# iter_dt 223.11ms; iter 200: train loss 3.13683
# --------------------------------------------------------------------------------
# Hello! It is nice to make me around! I’d be able to get in front of whatever, was doing, he are you.
# --------------------------------------------------------------------------------
# Hello! It is nice to him, howeveryone’s got the team I’ve got yeh.”
# --------------------------------------------------------------------------------
# Hello! It is nice to him.”
# --------------------------------------------------------------------------------
# Hello! It is nice to go through — it’s what he’s not in a long, afterful. Dumbledore in the Houserything?”
# --------------------------------------------------------------------------------
# Hello! It is nice to me when I’m not to get back in a bit time, it, it’s a second’s what’s a dragon!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be in it, with an armchair, they’re going up.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be in the Stone’s oldestions.
# --------------------------------------------------------------------------------
# Hello! It is nice to me!” Professor McGonagall called Harry’s head, who tried to see his father. “What are you?”
# --------------------------------------------------------------------------------
# Hello! It is nice to take himself, they were the back, then, if you’re so good.”
# --------------------------------------------------------------------------------
# Hello! It is nice to say he has a pair of course — ”
# iter_dt 222.91ms; iter 0: train loss 3.23991
# iter_dt 223.89ms; iter 100: train loss 3.17954
# iter_dt 226.42ms; iter 200: train loss 3.05732
# --------------------------------------------------------------------------------
# Hello! It is nice to the end of the last year, they were looking for them, not to get a broomstick in a few minutes as a week later, he was a greatering out, and they were going to see if anyone was talking to do, where he was trying to see that they could hear a great second room was doing this, because everyone was doing as though, who was about all the House Cup.
# --------------------------------------------------------------------------------
# Hello! It is nice to do? We mean, they have a school, an’ that’s not a small, well bestions in your nose, then, sir, we’re not be so I’ve read any idea.”
# --------------------------------------------------------------------------------
# Hello! It is nice to your father?
# --------------------------------------------------------------------------------
# Hello! It is nice to the mirror, that’s all in here?”
# --------------------------------------------------------------------------------
# Hello! It is nice to tell me all my life, and he’d just a good things I’ve got to a hundred and — I’ve got some o’ wizards. Right, he’s soccer, an’ it’s a large, an’ that’ fer a moment an’ yeh — this is the people, an’ I’ if yeh had ter get the same, even. You-Who — and every last’s not the best House
# --------------------------------------------------------------------------------
# Hello! It is nice to come and then, it must be easy?”
# --------------------------------------------------------------------------------
# Hello! It is nice to use around the Stone, and you take the rest of the Stone’s Stone,” said Professor McGonagall in her hand out her arms, looking at all over the ground, “You might be taken.”
# --------------------------------------------------------------------------------
# Hello! It is nice to his broom again, that?”
# --------------------------------------------------------------------------------
# Hello! It is nice to his heart, and your handkerm in a few times were a lot. He didn’t take some of tea until he was in the library, something could ask a few things that they were there, but he had been trying to asked what he was sure.
# --------------------------------------------------------------------------------
# Hello! It is nice to try and you out!”
# iter_dt 227.54ms; iter 0: train loss 3.15173
# iter_dt 225.42ms; iter 100: train loss 3.17791
# iter_dt 225.06ms; iter 200: train loss 2.99731
# --------------------------------------------------------------------------------
# Hello! It is nice to be here and that, Hermione!”
# --------------------------------------------------------------------------------
# Hello! It is nice to look at Hogwarts, though, can’t you tell us what are?”
# --------------------------------------------------------------------------------
# Hello! It is nice to get it, we’re sure we’ve got yer house in here.”
# --------------------------------------------------------------------------------
# Hello! It is nice to get my cupboard for?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be something to the letter from me?”
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to it here and your mother?”
# --------------------------------------------------------------------------------
# Hello! It is nice to keep your own friends! Look down!”
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# iter_dt 224.09ms; iter 0: train loss 3.01320
# iter_dt 226.47ms; iter 100: train loss 2.91303
# iter_dt 219.77ms; iter 200: train loss 2.83525
# --------------------------------------------------------------------------------
# Hello! It is nice to the best, you just one who are here somewhere to say?”
# --------------------------------------------------------------------------------
# Hello! It is nice to keep the Quaffle, but have been after all. It’s as well-to-bye to her. He pulled out of her first. He was talking about to the third floor in his head was trying to tell use it that he might have got the school than he wasn’t going to look at all. He’d left. There was almost to keep it, but he was quite after how he got into a small room, and were still
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to go and see — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to tell us, I’ve never even got the way, and everyone knows his head, he’s not like you?” said Hermione.
# --------------------------------------------------------------------------------
# Hello! It is nice to bed!”
# --------------------------------------------------------------------------------
# Hello! It is nice to get out now — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to find out an’ Hogwarts in trouble?”
# --------------------------------------------------------------------------------
# Hello! It is nice to a lot like this year? But I got an’ I suppose that’s a few that’s always like a bit so — I’ll never seen an’ I’ve got his name. You got some o’ the Quaffle with the same times. We’ve got it on the Bludgers, just Malfoy’s dangerous.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be out, and Slytherin I’ve done it and he’d make sure it’s not ter try an’ I’ll be the school.”
# iter_dt 225.94ms; iter 0: train loss 2.81083
# iter_dt 225.44ms; iter 100: train loss 2.81670
# iter_dt 222.98ms; iter 200: train loss 2.84350
# --------------------------------------------------------------------------------
# Hello! It is nice to Hogwarts! I will be here! I can take my broomstick back! Why did you can get past that?”
# --------------------------------------------------------------------------------
# Hello! It is nice to his brothers.”
# --------------------------------------------------------------------------------
# Hello! It is nice to him!”
# --------------------------------------------------------------------------------
# Hello! It is nice to me over here!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be safe. But I thought Hermione didn’t know about being in here, and Snape would be a chance’s very powerful as — if Dumbledore must know everyone wanted to do was going out. He told use me.” He strode off his feet, mutter. “Well, though, you think he’ve got that scar.”
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to come and be right?”
# --------------------------------------------------------------------------------
# Hello! It is nice to you again, but not be enough — You must be able to know we will know where your wand.”
# --------------------------------------------------------------------------------
# Hello! It is nice to our world! And I can we go up to bed. ...”
# --------------------------------------------------------------------------------
# Hello! It is nice to him, Harry?”
# iter_dt 227.89ms; iter 0: train loss 2.78295
# iter_dt 226.59ms; iter 100: train loss 2.77582
# iter_dt 225.92ms; iter 200: train loss 2.64219
# --------------------------------------------------------------------------------
# Hello! It is nice to us if you could meet you in five points, do you, Professor. ...”
# --------------------------------------------------------------------------------
# Hello! It is nice to me — anyway, I’ve just going to go to the name!”
# --------------------------------------------------------------------------------
# Hello! It is nice to take him from Ron’s heart, too!”
# --------------------------------------------------------------------------------
# Hello! It is nice to me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to kill him, so I want. ...
# --------------------------------------------------------------------------------
# Hello! It is nice to it to be, Weasley, and you are your father only me! But I suppose, we’re not only one for your own family, for you go, all our teeth will be in the third floor — I can stand her.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be all right.”
# --------------------------------------------------------------------------------
# Hello! It is nice to you when you see, sir, is important.”
# --------------------------------------------------------------------------------
# Hello! It is nice to the world, or something about that, but they might be able to think they were going with himself against it, all they are used for something?
# --------------------------------------------------------------------------------
# Hello! It is nice to see you on your own?”
# iter_dt 218.31ms; iter 0: train loss 2.67959
# iter_dt 227.11ms; iter 100: train loss 2.55294
# iter_dt 226.41ms; iter 200: train loss 2.55759
# --------------------------------------------------------------------------------
# Hello! It is nice to come from behind you,” Harry snarled.
# --------------------------------------------------------------------------------
# Hello! It is nice to use it again and she’s very angry, we just a thing — er — one more like magic — so — have a broomstick but they’ve got to find out how ter get yer letter.
# --------------------------------------------------------------------------------
# Hello! It is nice to take over your head, I hope, is it? I think you’ve got a good one more.”
# --------------------------------------------------------------------------------
# Hello! It is nice to my toad?”
# --------------------------------------------------------------------------------
# Hello! It is nice to bed!”
# --------------------------------------------------------------------------------
# Hello! It is nice to the school!”
# --------------------------------------------------------------------------------
# Hello! It is nice to go back to a school, Harry!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be just! You need to make an archway of some presents and that he’s old wand when it’s got two — he died in his face, too, because he had been so stupid people had been closer than it.
# --------------------------------------------------------------------------------
# Hello! It is nice to bed in this very difficult — well, if you’re a verything that you’ll be up with our mother, use it, an’ it’s gone — that’s why it’s what this might be doing of yours, an’ he’d best.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be able to be taken from my hands — and why you’d better do? Got that night something like a few people’s bigger. No one I could ask you, I say he? I could be something to do a few reason, that would best. ...”
# iter_dt 226.34ms; iter 0: train loss 2.52110
# iter_dt 225.13ms; iter 100: train loss 2.49374
# iter_dt 226.17ms; iter 200: train loss 2.45085
# --------------------------------------------------------------------------------
# Hello! It is nice to take over you here!”
# --------------------------------------------------------------------------------
# Hello! It is nice to Gryffindor, I will be in Slytherin!”
# --------------------------------------------------------------------------------
# Hello! It is nice to see what was trying to get him off a pair of Magic, like the Muggles that’s in Slytherin House Cup? You should have forgotten what it will be in for a class.”
# --------------------------------------------------------------------------------
# Hello! It is nice to talk to him by one of any first.” In the last move. The next second place is Harry was very hard to remember or angry, but he didn’t kill me like. No one’s why it didn’t do that day off, but I suppose they can’t speak to him afternoon at eleven o’clock the next morning. She and He turned her feet into a darkness.
# --------------------------------------------------------------------------------
# Hello! It is nice to Gryffindor for books to bed, and nothing terrible pain!”
# --------------------------------------------------------------------------------
# Hello! It is nice to bed, or anything, with that only is it?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be able to be able to say.”
# --------------------------------------------------------------------------------
# Hello! It is nice to give me, however, I want her it a lot of dragon! Now!” said Ron, but Hermione didn’t look so much as the other two of her good one could put up — she didn’t want to be the end as possible toward the ground.
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from it, so he was starting to find the Quidditch match!
# --------------------------------------------------------------------------------
# Hello! It is nice to talk to you.
# iter_dt 224.90ms; iter 0: train loss 2.39746
# iter_dt 225.14ms; iter 100: train loss 2.32533
# iter_dt 226.85ms; iter 200: train loss 2.36101
# --------------------------------------------------------------------------------
# Hello! It is nice to have a single questions to come and find me in that I award Gryffindor House Cup — I’ll be in five points.”
# --------------------------------------------------------------------------------
# Hello! It is nice to hear Harry, she’s got a bit of funny. I’m going to go and have to bed.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be easy to live, now, or we know you’re going to be in here, Weasley, and I gotta get any more important.”
# --------------------------------------------------------------------------------
# Hello! It is nice to you all over the most good.”
# --------------------------------------------------------------------------------
# Hello! It is nice to Gryffindor for the forest, then, I’m glad we’ll give you to us enough there tonight. I’ve only got a new few of this year.”
# --------------------------------------------------------------------------------
# Hello! It is nice to go, but before I want ter live, and get him, she’s a very fast about anything or like you. And I can keep it out of this year’s really well.”
# --------------------------------------------------------------------------------
# Hello! It is nice to make your parents to get yer parents, well, that’s Hermione will be able to go and get off to the platform. Yeh’d better get rid of any more than up, do magic, don’t you?”
# --------------------------------------------------------------------------------
# Hello! It is nice to do something that know about it, the last year? There happened to him if it just put a sort of son — he’ll know where to him they were sure he’d do make afternoon. Ron said, because Ron and Hermione were sure they were in the field.
# --------------------------------------------------------------------------------
# Hello! It is nice to be able to look at us and call me by his broomstick, and even when I’m going to be able to come and look!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be quiet for, Weasley, with some points up and Goyle, just as little it’s Cross.
# iter_dt 223.81ms; iter 0: train loss 2.21820
# iter_dt 225.28ms; iter 100: train loss 2.18860
# iter_dt 225.73ms; iter 200: train loss 2.20414
# --------------------------------------------------------------------------------
# Hello! It is nice to take me from my own?” snapped Ron. “How are you doing?”
# --------------------------------------------------------------------------------
# Hello! It is nice to use the school at Hogwarts?”
# --------------------------------------------------------------------------------
# Hello! It is nice to give me the one does.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be mad, but not until I have a toad.”
# --------------------------------------------------------------------------------
# Hello! It is nice to go when we can come in here!”
# --------------------------------------------------------------------------------
# Hello! It is nice to keep it?”
# --------------------------------------------------------------------------------
# Hello! It is nice to come up as the country.”
# --------------------------------------------------------------------------------
# Hello! It is nice to take over my mind, but I’ve only just going to say.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be good and Slytherin ’s already.”
# --------------------------------------------------------------------------------
# Hello! It is nice to the Stone!”
# iter_dt 225.98ms; iter 0: train loss 2.18527
# iter_dt 224.28ms; iter 100: train loss 2.09855
# iter_dt 223.69ms; iter 200: train loss 2.03961
# --------------------------------------------------------------------------------
# Hello! It is nice to be playing for yourself, boy, you know, this is like?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be grateful for some reason, with the rest of us are at Hogwarts! So I’m all right, you two!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be allowed to get him, all three of us if they didn’t know about. After all, I know I’d say, that’s all until I think it did to send you a bit more owl, or that’s all-t-headed dog. He says Malfoy’s going to do. Every Flavor Beans.” Hagrid must have changed their glasses and Harry, who did not to say when he was playing Quidditch, “I think
# --------------------------------------------------------------------------------
# Hello! It is nice to you all talk to me for?”
# --------------------------------------------------------------------------------
# Hello! It is nice to learn until they are not?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be right again, but even though. But he wasn’t very good.
# --------------------------------------------------------------------------------
# Hello! It is nice to be grateful for my opinion. You leave that one more or Voldemort’s talking about, Professor Quirrell, Snape.”
# --------------------------------------------------------------------------------
# Hello! It is nice to go looking for yourself, now.”
# --------------------------------------------------------------------------------
# Hello! It is nice to do to steal? If it’s a sort of dragon, an’ he’ dad lived.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be good, but as you can do know, you don’t think they’re really bad? Are you a letter, Professor.”
# iter_dt 227.87ms; iter 0: train loss 1.97853
# iter_dt 228.31ms; iter 100: train loss 2.01002
# iter_dt 225.41ms; iter 200: train loss 1.92163
# --------------------------------------------------------------------------------
# Hello! It is nice to learn until day ... Anyway, how many years never know, it’s very good.”
# --------------------------------------------------------------------------------
# Hello! It is nice to the others?”
# --------------------------------------------------------------------------------
# Hello! It is nice to the Stone!”
# --------------------------------------------------------------------------------
# Hello! It is nice to like that. If we do, it will be taken from Gryffindor.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be mad, Harry? Can’t you get this time? I’ve never seen your leg out of the back here tonight.”
# --------------------------------------------------------------------------------
# Hello! It is nice to know about Hogwarts! Of course — no, the Stone’s easy enough trying to catch, when I met him a few things I’m special, but I’m warning you — but I’m going to be in my side for Christmas.”
# --------------------------------------------------------------------------------
# Hello! It is nice to meet three of you in the class! How many years should be good I have managed to get himself from now, Dumbledore when we told me the Invisibility Cloak footsteps had given him before I could ask, too — er to find him by Professor Flitwick — Quirrell would never, Quirrell to stop him for something to catch him. ’Course, Quirrell was beaming at Quirrell. “I — I told him Malfoy — what I’m armed!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be able to move from home in the world — I might be too far if it’s a bit o’clock! A nice an’ all right,” Hagrid warned Harry, holding up a large box in his hands.
# --------------------------------------------------------------------------------
# Hello! It is nice to find me an hour, I’m sure.”
# --------------------------------------------------------------------------------
# Hello! It is nice to the first years!”
# iter_dt 226.64ms; iter 0: train loss 1.99623
# iter_dt 225.37ms; iter 100: train loss 1.88246
# iter_dt 225.41ms; iter 200: train loss 1.85793
# --------------------------------------------------------------------------------
# Hello! It is nice to stay here and make a few seconds and then get it, now that will be trouble into it — something that’s why he’s doing this.”
# --------------------------------------------------------------------------------
# Hello! It is nice to the world, but three-quarters will understand who’d been wrong.
# --------------------------------------------------------------------------------
# Hello! It is nice to my own?”
# --------------------------------------------------------------------------------
# Hello! It is nice to my House!”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop Snape or Herbology and in the air, who kept sure this was full of spilled with Hagrid. The rest of the first years crept across the dark hall, and off the Gryffindor common room, where he caught everyone else had been held to say to look at once. He had been having a good reason to look at what looked like this and was good-bye to them.
# --------------------------------------------------------------------------------
# Hello! It is nice to stop Malfoy!”
# --------------------------------------------------------------------------------
# Hello! It is nice to bed, though, had no good to stay with Crabbe and Goyle, and Goyle.
# --------------------------------------------------------------------------------
# Hello! It is nice to Mr. Potter, sir, don’t think of it was almost close behind me. Not all three of them have got the Quaffle and that they were expelled, and that nothing moved from Gringotts to the other team’s eyes Flint. Every Flavor Beans he put their heads and stared as they passed a few feet high voice:
# --------------------------------------------------------------------------------
# Hello! It is nice to come back here and bed to catch the others, though. I think he was going to be something to be sick.”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop her. You was only care about, a great, though. You know.”
# iter_dt 226.66ms; iter 0: train loss 1.90542
# iter_dt 223.70ms; iter 100: train loss 1.79902
# iter_dt 235.10ms; iter 200: train loss 1.71297
# --------------------------------------------------------------------------------
# Hello! It is nice to the Dark Arts! Now!”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop you the same.
# --------------------------------------------------------------------------------
# Hello! It is nice to stop him!”
# --------------------------------------------------------------------------------
# Hello! It is nice to Mr. Potter, Ginny, and it must have had to think they like something else’s guarding the Stone against this, not knowing you did — you know, it’s not really.”
# --------------------------------------------------------------------------------
# Hello! It is nice to see my toad, I’m sure, so well — I’m going to Gryffindor, it’s got a week.”
# --------------------------------------------------------------------------------
# Hello! It is nice to keep it a little me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop me as young as you go,” said Malfoy.
# --------------------------------------------------------------------------------
# Hello! It is nice to catch it, but it’s no big plastic old rowboat and a few feet away from the end as they walked forward and after how to get round Wood and turned out to be the library, but they reached a few seconds — they were saying, not knowing what they were looking for, they wanted to get back to the other two.
# --------------------------------------------------------------------------------
# Hello! It is nice to Mr. Ollivander!”
# --------------------------------------------------------------------------------
# Hello! It is nice to use it, even if you can play,
# iter_dt 224.70ms; iter 0: train loss 1.68365
# iter_dt 224.46ms; iter 100: train loss 1.68748
# iter_dt 229.92ms; iter 200: train loss 1.64671
# --------------------------------------------------------------------------------
# Hello! It is nice to stop Malfoy!”
# --------------------------------------------------------------------------------
# Hello! It is nice to take over your bus, like the times a week. Seven! House me!”
# --------------------------------------------------------------------------------
# Hello! It is nice to take care for the Dark Arts! Harry!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be grateful for Gryffindor, all of you!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from her to beames, though, why it’s that dog was eating anything this cloak that might help him get rid of Norbert! What did you were going to be really first?
# --------------------------------------------------------------------------------
# Hello! It is nice to be afraid, Harry, as usual, everybody knowing you’ve got a broomstick or they’d never heard of Dudley! He’s got something!”
# --------------------------------------------------------------------------------
# Hello! It is nice to come from the key to the game!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be allowed to bed. It’s not really really full of dangerous because it’s always best, that’s no one can get this time. That’s what we do, no one does. Not even after all, I don’t know what on Halloween! The Gryffindor is that I can be in there and it’s all been waiting for.”
# --------------------------------------------------------------------------------
# Hello! It is nice to see another word ... why would have never heard of Hogwarts!
# --------------------------------------------------------------------------------
# Hello! It is nice to like a prefect, and I’ve got my own Quidditch Cup and I’m the only one who find my class.”
# iter_dt 224.02ms; iter 0: train loss 1.61420
# iter_dt 224.39ms; iter 100: train loss 1.59732
# iter_dt 227.96ms; iter 200: train loss 1.49854
# --------------------------------------------------------------------------------
# Hello! It is nice to see what I’ve done to, for you,” said Wood, peering at them. “Thanks for your brother, Hermione, our feet. You may bet I’ll take the Stone from Gryffindor Tower.”
# --------------------------------------------------------------------------------
# Hello! It is nice to see where a Muggle sweet my cupboard — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to beside him!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from my office, Professor Flitwick!”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop saying the Stone for dear?”
# --------------------------------------------------------------------------------
# Hello! It is nice to beside himself.
# --------------------------------------------------------------------------------
# Hello! It is nice to be nice to come from that moment!”
# ...
# --------------------------------------------------------------------------------
# Hello! It is nice to eat or drink all day. By nightfall Dudley was howling. He’d never had such a bad day in his life. He was hungry, he’d missed five television programs he’d wanted to see, and he’d never gone so long without blowing up an alien on his computer.
# iter_dt 230.13ms; iter 0: train loss 0.26547
# iter_dt 223.22ms; iter 100: train loss 0.24925
# iter_dt 229.00ms; iter 200: train loss 0.24778
# --------------------------------------------------------------------------------
# Hello! It is nice to come!”
# --------------------------------------------------------------------------------
# Hello! It is nice to come back to the castle for dinner, their pockets weighed down with rock cakes they’d been too polite to refuse, Harry thought that none of the lessons he’d had so far had given him as much to think about as tea with Hagrid. Had Hagrid collected that package just in time? Where was it now? And did Hagrid know something about Snape that he didn’t want to tell Harry?
# --------------------------------------------------------------------------------
# Hello! It is nice to drink something please.”
# --------------------------------------------------------------------------------
# Hello! It is nice to Hogwarts. I award Gryffindor House fifty points.”
# --------------------------------------------------------------------------------
# Hello! It is nice to London at Hogwarts.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be enjoying yourself our desperate to get shot at the end of a patch of moonlight.
# --------------------------------------------------------------------------------
# Hello! It is nice to come!”
# --------------------------------------------------------------------------------
# Hello! It is nice to movements that is at the planets?”
# --------------------------------------------------------------------------------
# Hello! It is nice to death, that one will get you back through the purple flames?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be prepared. It is times a secret, and a pair of glasses. How strange.
# iter_dt 221.84ms; iter 0: train loss 0.24821
# iter_dt 222.86ms; iter 100: train loss 0.24973
# iter_dt 225.29ms; iter 200: train loss 0.26617
# --------------------------------------------------------------------------------
# Hello! It is nice to drink that to death, or doubled back to pass us in the corridors again, staring. Harry wished they wouldn’t, because he was trying to concentrate on finding his way to classes.
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from the touch, like Flitwick, was a big plastic number nine over one platform and a big plastic number ten over the one next to it, and in the middle, nothing at all.
# --------------------------------------------------------------------------------
# Hello! It is nice to stop Muggles from everything.”
# --------------------------------------------------------------------------------
# Hello! It is nice to its feet, or tickled them in exactly the right place, and doors that weren’t really doors at all, but solid walls just pretending. It was also very hard to remember where anything was, because it all seemed to move around a lot. The people in the portraits kept going to visit each other, and Harry was sure the coats of armor could walk.
# --------------------------------------------------------------------------------
# Hello! It is nice to move while any of you will hardly believe this is magic. I don’t expect you will really understand the beauty of the softly simmering cauldron with its paws and fell to its knees, then it slumped to the ground, fast asleep.
# --------------------------------------------------------------------------------
# Hello! It is nice to move — a great wizard, you know.”
# --------------------------------------------------------------------------------
# Hello! It is nice to bedroom, dear?”
# --------------------------------------------------------------------------------
# Hello! It is nice to see ... at Hogwarts, I suppose? I’ve g-got to p-pick up a new b- book on vampires, m-myself.” He looked terrified at the very thought.
# --------------------------------------------------------------------------------
# Hello! It is nice to be reaching Hogwarts in five minutes’ time. Please leave your luggage on the train, it will be taken to the school separately.”
# --------------------------------------------------------------------------------
# Hello! It is nice to centaurs, I hope this is one of those times.”
# iter_dt 225.46ms; iter 0: train loss 0.24685
# iter_dt 223.15ms; iter 100: train loss 0.24177
# iter_dt 224.63ms; iter 200: train loss 0.23816
# --------------------------------------------------------------------------------
# Hello! It is nice to Hogwarts in your family!”
# --------------------------------------------------------------------------------
# Hello! It is nice to return to power, who has clung to life, awaiting their chance?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be allowed to Hogwarts at Hogwarts — ”
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from Gryffindor for this, All right, Percy, you go first.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from Gryffindor for this,” said Professor McGonagall. “I’m very disappointed in you. If you’re not hurt at all, you’d better get off to Gryffindor Tower. Students are finishing the feast in their Houses.”
# --------------------------------------------------------------------------------
# Hello! It is nice to er around our world. You know what everyone’s saying? About why he’s disappeared?
# --------------------------------------------------------------------------------
# Hello! It is nice to be brave or any more points, all the same, just as no two unicorns, dragons, or phoenixes are quite the same. And of course, you will never get such good results with another wizard’s wand.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be older than I will be sorted. “Really, I award Gryffindor House sixty points.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be taken from Gryffindor for this,” said Professor McGonagall. “I’m very disappointed in you. If you’re not hurt at all, you’d better get off to Gryffindor Tower. Students are finishing the feast in their Houses.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be far easier than I thought it would be,” said Hermione as they joined the crowds flocking out onto the sunny grounds. “I needn’t have learned about the 1637 Werewolf Code of Conduct or the uprising of Elfric the Eager.”
# iter_dt 227.35ms; iter 0: train loss 0.22951
# iter_dt 228.10ms; iter 100: train loss 0.25116
# iter_dt 224.93ms; iter 200: train loss 0.24030
# --------------------------------------------------------------------------------
# Hello! It is nice to be gamekeeper yourself when you leave Hogwarts, I suppose — that hut of Hagrid’s must seem like a palace compared to what your family’s used to.”
# --------------------------------------------------------------------------------
# Hello! It is nice to come round my house this summer. Anyway, maybe it only shows dead people. Shame about not finding Flamel, though. Have some bacon or something, why aren’t you eating anything?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be easy enough to cover two of us and Norbert.”
# --------------------------------------------------------------------------------
# Hello! It is nice to In me.”
# --------------------------------------------------------------------------------
# Hello! It is nice to guard to follow him away, took one point will get us out of the few weeks ago for afternoon. “Wood told me.”
# --------------------------------------------------------------------------------
# Hello! It is nice to be sick.” He followed Percy through the hole until he was hanging on by his fingertips. Then he looked up at Ron and said, “If anything happens to me, don’t follow. Go straight to the owlery and send Hedwig to Dumbledore, right?”
# --------------------------------------------------------------------------------
# Hello! It is nice to touch my House, Mr. Potter, Malfoy!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be brave or anything, saying the name,” said Harry, “I just never knew you shouldn’t. See what I mean? I’ve got loads to learn. ... I bet,” he added, voicing for the first time something that had been worrying him a lot lately, “I bet I’m the worst in the class.”
# --------------------------------------------------------------------------------
# Hello! It is nice to point House silver boats of thick, rich gravy and cranberry sauce — and stacks of wizard crackers every few feet along the table. These fantastic party favors were nothing like the feeble Muggle ones the Dursleys usually bought, with their little plastic toys and their flimsy paper hats inside. Harry pulled a wizard cracker with Fred and it didn’t just bang, it went off with a blast like a cannon and engulfed them all in a cloud of blue
# --------------------------------------------------------------------------------
# Hello! It is nice to stop Muggles from the Muggles that there’s still witches an’ wizards up an’ down the country.”
# iter_dt 223.30ms; iter 0: train loss 0.24421
# iter_dt 223.93ms; iter 100: train loss 0.23552
# iter_dt 225.63ms; iter 200: train loss 0.23365
# --------------------------------------------------------------------------------
# Hello! It is nice to be chucked out an’ made ter live as a Muggle!”
# --------------------------------------------------------------------------------
# Hello! It is nice to move into that ... but the old chessmen weren’t a drawback at all. Ron knew them so well he never had trouble getting them to do what he wanted.
# --------------------------------------------------------------------------------
# Hello! It is nice to be sorted,” she said. “Mrs. Figg’s broken her leg. She can’t take him.” She jerked her head in Harry’s direction.
# --------------------------------------------------------------------------------
# Hello! It is nice to be chucked out an’ made ter live as a Muggle!”
# --------------------------------------------------------------------------------
# Hello! It is nice to be sick.”
# --------------------------------------------------------------------------------
# Hello! It is nice to Voldemort!”
# --------------------------------------------------------------------------------
# Hello! It is nice to give it to those rare occasions when the true story is even more strange and exciting than the wild rumors. Harry told them everything: Quirrell; the mirror; the Stone; and Voldemort. Ron and Hermione were a very good audience; they gasped in all the right places, and when Harry told them what was under Quirrell’s turban, Hermione screamed out loud.
# --------------------------------------------------------------------------------
# Hello! It is nice to be offended,” she said shortly. “I have the Mirror of Erised shows us all?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be killed. He left Quirrell to die; he shows just as little mercy to his followers as his enemies. Nevertheless, Harry, while you may only have delayed his return to power, it will merely take someone else who is prepared to fight what seems a losing battle next time — and if he is delayed again, and again, why, he may never return to power.”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop the magic-places, Severus ...”
# iter_dt 224.57ms; iter 0: train loss 0.23628
# iter_dt 229.22ms; iter 100: train loss 0.22699
# iter_dt 227.98ms; iter 200: train loss 0.22523
# --------------------------------------------------------------------------------
# Hello! It is nice to catch the end, he nearly sat on it!” Hermione screamed, leaping onto her seat to watch as Harry sped straight at Snape — she didn’t even notice Malfoy and Ron rolling around under her seat, or the scuffles and yelps coming from the whirl of fists that was Neville, Crabbe, and Goyle.
# --------------------------------------------------------------------------------
# Hello! It is nice to Flint!”
# --------------------------------------------------------------------------------
# Hello! It is nice to pass these?”
# --------------------------------------------------------------------------------
# Hello! It is nice to be easy. ...”
# --------------------------------------------------------------------------------
# Hello! It is nice to its own club. ... They worked him a bit of a great Muggle like you won’t stop him,” growled Hagrid. “Stop Lily an’ James Potter’s son goin’ ter Hogwarts! Yer mad. His name’s been down ever since he was born. He’s off ter the finest school of witchcraft and wizardry in the world. Seven years there and he won’t know himself. He’ll
# --------------------------------------------------------------------------------
# Hello! It is nice to catch the key to the door!”
# --------------------------------------------------------------------------------
# Hello! It is nice to its own wand. It slope, we need a little change of decoration.”
# --------------------------------------------------------------------------------
# Hello! It is nice to catch out!”
# --------------------------------------------------------------------------------
# Hello! It is nice to stop Muggles from going down to the hospital wing! You leave those brooms where they are or you’ll be out of Hogwarts before you can say ‘Quidditch.’ Come on, dear.”
# --------------------------------------------------------------------------------
# Hello! It is nice to catch the key to the door!”
# iter_dt 227.30ms; iter 0: train loss 0.23053
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9eecaa57a447> in <module>
#      37
#      38 while True:
# ---> 39   trainer.run()
#      40   # torch.save(model.state_dict(), 'harryGPT.pt')
#      41   # now let's perform some evaluation
#
# /content/bpe/4-generate/minGPT/mingpt/trainer.py in run(self)
#      95             # backprop and update the parameters
#      96             model.zero_grad(set_to_none=True)
# ---> 97             self.loss.backward()
#      98             torch.nn.utils.clip_grad_norm_(model.parameters(), config.grad_norm_clip)
#      99             self.optimizer.step()
#
# /usr/local/lib/python3.9/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     486                 inputs=inputs,
#     487             )
# --> 488         torch.autograd.backward(
#     489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#
# /usr/local/lib/python3.9/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
  model.eval()
  generate(prompt='Oh no, my', num_samples=10, steps=100)
# Out:
# --------------------------------------------------------------------------------
# Oh no, my mumbled, ’cause he was gettin’ himself power, all right. Dark days, Harry. Didn’t know who ter trust, didn’t dare get friendly with strange wizards or witches . . terrible things happened. He was takin’ over. ’Course, some stood up to him — an’ he killed ’em. Horribly. One o’ the only safe places left was Hogwarts. Reckon Dumbledore’s the only one You
# --------------------------------------------------------------------------------
# Oh no, my dratted sister being what she was? Oh, she got a letter just like that and disappeared off to that — that school — and came home every vacation with her pockets full of frog spawn, turning teacups into rats. I was the only one who saw her for what she was — a freak!
# --------------------------------------------------------------------------------
# Oh no, my gran brought me up and she’s a witch,” said Neville, “but the family thought I was all- Muggle for ages. My Great Uncle Algie kept trying to start tapping the ticket inspector’s stand between platforms nine and ten.
# --------------------------------------------------------------------------------
# Oh no, my mistake — I didn’t see you — of course I didn’t, you’re invisible — forgive old Peevsie his little joke, sir.”
# --------------------------------------------------------------------------------
# Oh no, my opinion — asked for all they got, getting mixed up with these wizarding types — just what I expected, always knew they’d come to a sticky end — ”
# --------------------------------------------------------------------------------
# Oh no, my mistake — I didn’t see you — of course I didn’t, you’re invisible — forgive old Peevsie his little joke, sir.”
# --------------------------------------------------------------------------------
# Oh no, my brother, Charlie — Charlie. In Romania. Studying dragons. We could send Norbert to him. Charlie can take care of him and then put him back in the wild!”
# --------------------------------------------------------------------------------
# Oh no, my opinion — asked for all they got, getting mixed up with these wizarding types — just what I expected, always knew they’d come to a sticky end — ”
# --------------------------------------------------------------------------------
# Oh no, my mother and father, and father, oh no, it was Lily this and Lily that, they were proud of having a witch in the family!”
# --------------------------------------------------------------------------------
# Oh no, my dear sir, for nothing could upset me today! Rejoice, for You- Know-Who has gone at last! Even Muggles like yourself should be celebrating, this happy, happy day!”

# %%
torch.save(model.state_dict(), 'harryGPT.pt')
